# %%
ab = open('AB.txt','r', encoding="UTF-8")
ba = open('BA.txt','w')
for line in ab:
    if (line[0].strip() != '<') and (len(line) > 2):
        print(line)
        ba.write(line.split("--")[1].strip() + " -- " + line.split("--")[0].strip()+"\n")
ab.close()
ba.close()
# Out:
# hello -- Привет
#
# excuse me -- Простите
#
# Hello. How have you been? -- Привет как у тебя дела?
#
# i'm sorry -- прошу прощения
#
# Excuse me. How much is this? -- Прошу прощения. Сколько это стоит?
#
# I’m sorry. It was a typo. -- Мне жаль. Это была опечатка.
#
# Good night. -- Спокойной ночи.
#
# Good night, grandma. -- Спокойной ночи бабушка
#
# Nice to meet you. -- Приятно познакомиться.
#
# Please come in. Nice to meet you. -- Пожалуйста, входите. Приятно познакомиться.
#
# How are you? -- Как ты?
#
# It’s been a long time. How are you? -- Прошло много времени. Как ты?
#
# Yes -- Да
#
# Yes, this one please. -- Да, вот это, пожалуйста.
#
# No. -- Нет
#
# No, I haven’t eaten yet. -- Нет, я еще не ел.
#
# Thank you. -- Спасибо
#
# Thank you very much for the invitation. -- Большое вам спасибо за приглашение.
#
# Goodbye -- До свидания
#
# Goodbye. See you again! -- До свидания. Увидимся снова!
#
# bad -- плохой
#
# Be careful of bad people -- Будьте осторожны с плохими людьми.
# ...
